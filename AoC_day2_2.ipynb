# %%
scoreMap = { 'X':1, 'Y':2, 'Z':3 }
winMap = { 'A': {
                'X' : 3,
                'Y' : 6,
                'Z' : 0,
                },
            'B': {
                'X' : 0,
                'Y' : 3,
                'Z' : 6,
                },
            'C': {
                'X' : 6,
                'Y' : 0,
                'Z' : 3,
            }
        }

# %%
a = input().split(' ')
b = [ ( a[i], a[i+1] ) for i in range( 0, len( a ), 2 ) ]
print( len( b ) )
# Out:
# 5000
# 2500
# ...

# %%
score = 0
for enemy, you in b:
    score += scoreMap[ you ]
    score += winMap[enemy][you]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 score = 0
# ----> 2 for enemy, you in b:
#       3     score += scoreMap[ you ]
#       4     score += winMap[enemy][you]
#
# NameError: name 'b' is not defined
